# %% [markdown]
# # Aperçu du dataset

# %% [markdown]
# imports

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# charger le fichier

# %%
# Charger le fichier fusionné
df = pd.read_csv("C:/Users/bamoi/OneDrive - Groupe ESAIP/$ PSIR/experimentation/repo/psir-ml-imputation/data/raw/data farouk/merged/variables lisibles/hta_nhanes_complet_variables_fr.csv")

# %% [markdown]
# Aperçu des 5 premières lignes

# %%
print("🧾 Aperçu des premières lignes :")
print(df.head())
# Out:
# 🧾 Aperçu des premières lignes :
#        SEQN  age_annees  sexe_1H_2F  ethnie_code  hta_diagnostiquee  \
# 0  109263.0         2.0         1.0          5.0                NaN
# 1  109264.0        13.0         2.0          1.0                NaN
# 2  109265.0         2.0         1.0          3.0                NaN
# 3  109266.0        29.0         2.0          5.0                2.0
# 4  109267.0        21.0         2.0          2.0                2.0
#
#    hta_traitement  tension_systolique_1_mmHg  tension_systolique_2_mmHg  \
# 0             NaN                        NaN                        NaN
# 1             NaN                      109.0                      109.0
# 2             NaN                        NaN                        NaN
# 3             NaN                       99.0                       99.0
# 4             NaN                        NaN                        NaN
#
#    tension_systolique_3_mmHg  tension_diastolique_1_mmHg  ...  \
# 0                        NaN                         NaN  ...
# 1                      106.0                        67.0  ...
# 2                        NaN                         NaN  ...
# 3                       99.0                        56.0  ...
# 4                        NaN                         NaN  ...
#
#    sodium_jour1_mg  sodium_jour2_mg  activite_moderate_10min  \
# 0           2456.0           1390.0                      NaN
# 1           1703.0           2687.0                      NaN
# 2           2221.0           1761.0                      NaN
# 3           2001.0           3439.0                      2.0
# 4              NaN              NaN                      2.0
#
#    activite_vigoureuse_10min  cholesterol_total_mgdl  antecedent_cardiaque  \
# 0                        NaN                     NaN                   NaN
# 1                        NaN                   166.0                   NaN
# 2                        NaN                     NaN                   NaN
# 3                        2.0                   195.0                   2.0
# 4                        2.0                     NaN                   2.0
#
#    antecedent_familial_cardiaque  tension_sys_moy_mmHg  tension_dia_moy_mmHg  \
# 0                            NaN                   NaN                   NaN
# 1                            NaN                 108.0             67.000000
# 2                            NaN                   NaN                   NaN
# 3                            2.0                  99.0             54.333333
# 4                            2.0                   NaN                   NaN
#
#      HTA
# 0  False
# 1  False
# 2  False
# 3  False
# 4  False
#
# [5 rows x 31 columns]

# %% [markdown]
# Dimensions du dataset

# %%
print("\n🔢 Dimensions du dataset :")
print(f"Nombre de lignes : {df.shape[0]}")
print(f"Nombre de colonnes : {df.shape[1]}")
# Out:
# 🔢 Dimensions du dataset :
# Nombre de lignes : 15560
# Nombre de colonnes : 31

# %% [markdown]
# Liste des noms de colonnes

# %%
print("\n📌 Noms des variables :")
for col in df.columns:
    print(f"- {col}")
# Out:
# 📌 Noms des variables :
# - SEQN
# - age_annees
# - sexe_1H_2F
# - ethnie_code
# - hta_diagnostiquee
# - hta_traitement
# - tension_systolique_1_mmHg
# - tension_systolique_2_mmHg
# - tension_systolique_3_mmHg
# - tension_diastolique_1_mmHg
# - tension_diastolique_2_mmHg
# - tension_diastolique_3_mmHg
# - frequence_cardiaque_1_bpm
# - frequence_cardiaque_2_bpm
# - frequence_cardiaque_3_bpm
# - poids_kg
# - taille_cm
# - imc
# - tour_taille_cm
# - a_fume_100_cigarettes
# - statut_tabagique
# - sodium_jour1_mg
# - sodium_jour2_mg
# - activite_moderate_10min
# - activite_vigoureuse_10min
# - cholesterol_total_mgdl
# - antecedent_cardiaque
# - antecedent_familial_cardiaque
# - tension_sys_moy_mmHg
# - tension_dia_moy_mmHg
# - HTA

# %% [markdown]
# # Valeurs manquantes

# %% [markdown]
# 🔍 Compter les valeurs manquantes par colonne

# %%
print("📉 Valeurs manquantes par colonne :")
print(df.isna().sum())
# Out:
# 📉 Valeurs manquantes par colonne :
# SEQN                                 0
# age_annees                           0
# sexe_1H_2F                           0
# ethnie_code                          0
# hta_diagnostiquee                 5365
# hta_traitement                   11963
# tension_systolique_1_mmHg         5208
# tension_systolique_2_mmHg         5233
# tension_systolique_3_mmHg         5274
# tension_diastolique_1_mmHg        5208
# tension_diastolique_2_mmHg        5233
# tension_diastolique_3_mmHg        5274
# frequence_cardiaque_1_bpm         6089
# frequence_cardiaque_2_bpm         6112
# frequence_cardiaque_3_bpm         6148
# poids_kg                          1485
# taille_cm                         2403
# imc                               2423
# tour_taille_cm                    2986
# a_fume_100_cigarettes             5867
# statut_tabagique                 13816
# sodium_jour1_mg                   3168
# sodium_jour2_mg                   4933
# activite_moderate_10min           5867
# activite_vigoureuse_10min         5867
# cholesterol_total_mgdl            4732
# antecedent_cardiaque              6328
# antecedent_familial_cardiaque     6328
# tension_sys_moy_mmHg              5207
# tension_dia_moy_mmHg              5207
# HTA                                  0
# dtype: int64

# %% [markdown]
# 🔢 Proportion (%) de valeurs manquantes

# %%
print("\n📊 Pourcentage de valeurs manquantes :")
missing_pct = df.isna().mean().round(3) * 100
print(missing_pct.sort_values(ascending=False))
# Out:
# 📊 Pourcentage de valeurs manquantes :
# statut_tabagique                 88.8
# hta_traitement                   76.9
# antecedent_cardiaque             40.7
# antecedent_familial_cardiaque    40.7
# frequence_cardiaque_3_bpm        39.5
# frequence_cardiaque_2_bpm        39.3
# frequence_cardiaque_1_bpm        39.1
# a_fume_100_cigarettes            37.7
# activite_moderate_10min          37.7
# activite_vigoureuse_10min        37.7
# hta_diagnostiquee                34.5
# tension_systolique_3_mmHg        33.9
# tension_diastolique_3_mmHg       33.9
# tension_diastolique_2_mmHg       33.6
# tension_systolique_2_mmHg        33.6
# tension_diastolique_1_mmHg       33.5
# tension_systolique_1_mmHg        33.5
# tension_sys_moy_mmHg             33.5
# tension_dia_moy_mmHg             33.5
# sodium_jour2_mg                  31.7
# cholesterol_total_mgdl           30.4
# sodium_jour1_mg                  20.4
# tour_taille_cm                   19.2
# imc                              15.6
# taille_cm                        15.4
# poids_kg                          9.5
# ethnie_code                       0.0
# sexe_1H_2F                        0.0
# age_annees                        0.0
# SEQN                              0.0
# HTA                               0.0
# dtype: float64

# %% [markdown]
# 📋 Visualisation simple : top 10 colonnes les plus manquantes

# %%
missing_pct.sort_values(ascending=False).head(10).plot.bar(figsize=(10, 5))
plt.title("🔧 % de valeurs manquantes par variable (Top 10)")
plt.ylabel("Pourcentage de valeurs manquantes")
plt.xlabel("Variables")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\bamoi\AppData\Local\Temp\ipykernel_21880\2254821538.py:6: UserWarning: Glyph 128295 (\N{WRENCH}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\bamoi\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128295 (\N{WRENCH}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # Statistiques descriptives

# %% [markdown]
# 📊 Statistiques descriptives des variables numériques

# %%
print("📈 Statistiques descriptives (variables numériques) :")
print(df.describe().T)
# Out:
# 📈 Statistiques descriptives (variables numériques) :
#                                  count           mean          std  \
# SEQN                           15560.0  117042.500000  4491.929430
# age_annees                     15560.0      33.742481    25.320532
# sexe_1H_2F                     15560.0       1.503792     0.500002
# ethnie_code                    15560.0       3.249871     1.222644
# hta_diagnostiquee              10195.0       1.655419     0.540174
# hta_traitement                  3597.0       1.095635     0.376264
# tension_systolique_1_mmHg      10352.0     120.004637    19.950131
# tension_systolique_2_mmHg      10327.0     119.732255    19.788502
# tension_systolique_3_mmHg      10286.0     119.681898    19.641619
# tension_diastolique_1_mmHg     10352.0      72.035742    12.416883
# tension_diastolique_2_mmHg     10327.0      71.503825    12.436839
# tension_diastolique_3_mmHg     10286.0      71.258798    12.405156
# frequence_cardiaque_1_bpm       9471.0      71.183824    12.285039
# frequence_cardiaque_2_bpm       9448.0      71.946655    12.360577
# frequence_cardiaque_3_bpm       9412.0      72.550892    12.530454
# poids_kg                       14075.0      65.426380    33.331880
# taille_cm                      13157.0     156.490188    22.621413
# imc                            13137.0      26.656847     8.419842
# tour_taille_cm                 12574.0      89.669135    23.150206
# a_fume_100_cigarettes           9693.0       1.601981     0.512981
# statut_tabagique                1744.0      24.850917    10.393112
# sodium_jour1_mg                12392.0    3150.722805  1810.857708
# sodium_jour2_mg                10627.0    2872.628305  1609.930117
# activite_moderate_10min         9693.0       1.755390     0.471760
# activite_vigoureuse_10min       9693.0       1.573094     0.533974
# cholesterol_total_mgdl         10828.0     177.463521    40.355743
# antecedent_cardiaque            9232.0       1.715121     0.601227
# antecedent_familial_cardiaque   9232.0       2.035854     1.129812
# tension_sys_moy_mmHg           10353.0     119.810103    19.473950
# tension_dia_moy_mmHg           10353.0      71.593838    12.054363
#
#                                         min        25%            50%  \
# SEQN                           1.092630e+05  113152.75  117042.500000
# age_annees                     5.397605e-79      10.00      30.000000
# sexe_1H_2F                     1.000000e+00       1.00       2.000000
# ethnie_code                    1.000000e+00       3.00       3.000000
# hta_diagnostiquee              1.000000e+00       1.00       2.000000
# hta_traitement                 1.000000e+00       1.00       1.000000
# tension_systolique_1_mmHg      5.200000e+01     106.00     117.000000
# tension_systolique_2_mmHg      5.400000e+01     106.00     116.000000
# tension_systolique_3_mmHg      5.500000e+01     106.00     117.000000
# tension_diastolique_1_mmHg     3.100000e+01      63.00      71.000000
# tension_diastolique_2_mmHg     2.800000e+01      63.00      71.000000
# tension_diastolique_3_mmHg     3.000000e+01      63.00      70.000000
# frequence_cardiaque_1_bpm      3.400000e+01      62.00      70.000000
# frequence_cardiaque_2_bpm      3.400000e+01      63.00      71.000000
# frequence_cardiaque_3_bpm      3.500000e+01      63.75      72.000000
# poids_kg                       3.200000e+00      42.30      68.100000
# taille_cm                      7.830000e+01     151.10     162.100000
# imc                            1.190000e+01      20.40      25.800000
# tour_taille_cm                 4.000000e+01      73.30      91.000000
# a_fume_100_cigarettes          1.000000e+00       1.00       2.000000
# statut_tabagique               5.397605e-79      20.00      30.000000
# sodium_jour1_mg                5.397605e-79    1938.00    2830.000000
# sodium_jour2_mg                7.000000e+00    1783.00    2615.000000
# activite_moderate_10min        1.000000e+00       2.00       2.000000
# activite_vigoureuse_10min      1.000000e+00       1.00       2.000000
# cholesterol_total_mgdl         7.100000e+01     149.00     173.000000
# antecedent_cardiaque           1.000000e+00       1.00       2.000000
# antecedent_familial_cardiaque  1.000000e+00       2.00       2.000000
# tension_sys_moy_mmHg           7.233333e+01     106.00     116.666667
# tension_dia_moy_mmHg           3.800000e+01      63.00      70.666667
#
#                                      75%            max
# SEQN                           120932.25  124822.000000
# age_annees                         56.00      80.000000
# sexe_1H_2F                          2.00       2.000000
# ethnie_code                         4.00       5.000000
# hta_diagnostiquee                   2.00       9.000000
# hta_traitement                      1.00       9.000000
# tension_systolique_1_mmHg         130.00     225.000000
# tension_systolique_2_mmHg         130.00     222.000000
# tension_systolique_3_mmHg         130.00     220.000000
# tension_diastolique_1_mmHg         80.00     151.000000
# tension_diastolique_2_mmHg         79.00     146.000000
# tension_diastolique_3_mmHg         79.00     145.000000
# frequence_cardiaque_1_bpm          79.00     142.000000
# frequence_cardiaque_2_bpm          80.00     141.000000
# frequence_cardiaque_3_bpm          80.00     147.000000
# poids_kg                           86.30     254.300000
# taille_cm                         171.30     199.600000
# imc                                31.40      92.300000
# tour_taille_cm                    105.40     187.500000
# a_fume_100_cigarettes               2.00       9.000000
# statut_tabagique                   30.00      99.000000
# sodium_jour1_mg                  3993.25   25949.000000
# sodium_jour2_mg                  3648.50   24854.000000
# activite_moderate_10min             2.00       9.000000
# activite_vigoureuse_10min           2.00       9.000000
# cholesterol_total_mgdl            201.00     446.000000
# antecedent_cardiaque                2.00       9.000000
# antecedent_familial_cardiaque       2.00       9.000000
# tension_sys_moy_mmHg              130.00     218.666667
# tension_dia_moy_mmHg               79.00     143.666667

# %% [markdown]
# 📋 Statistiques descriptives des variables catégorielles ou booléennes

# %%
print("\n📘 Statistiques descriptives (variables catégorielles) :")
colonnes_cat = df.select_dtypes(include=["object", "category", "bool"]).columns

for col in colonnes_cat:
    print(f"\n▶ {col}")
    print(df[col].value_counts(dropna=False))
# Out:
# 📘 Statistiques descriptives (variables catégorielles) :
#
# ▶ HTA
# HTA
# False    11338
# True      4222
# Name: count, dtype: int64

# %% [markdown]
# # Visualisation des distributions

# %% [markdown]
# Configuration de style pour seaborn

# %%
sns.set(style="whitegrid")

# %% [markdown]
# 📌 Variables continues à visualiser

# %%
vars_continues = [
    "age_annees", "imc", "tension_sys_moy_mmHg", "tension_dia_moy_mmHg",
    "cholesterol_total_mgdl", "poids_kg", "taille_cm", "sodium_jour1_mg"
]

# %% [markdown]
# 📈 Histogrammes

# %%
for var in vars_continues:
    plt.figure(figsize=(8, 4))
    sns.histplot(df[var], kde=True, bins=30, color="skyblue")
    plt.title(f"Distribution de {var}")
    plt.xlabel(var)
    plt.ylabel("Nombre de personnes")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# 📊 Boxplots comparant chaque variable avec HTA

# %%
for var in vars_continues:
    plt.figure(figsize=(8, 4))
    sns.boxplot(x="HTA", y=var, data=df, palette="Set2")
    plt.title(f"{var} selon la présence d'hypertension")
    plt.xlabel("HTA (False = non, True = oui)")
    plt.ylabel(var)
    plt.tight_layout()
    plt.show()
# Out:
# C:\Users\bamoi\AppData\Local\Temp\ipykernel_21880\296896386.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="HTA", y=var, data=df, palette="Set2")
# C:\Users\bamoi\AppData\Local\Temp\ipykernel_21880\296896386.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="HTA", y=var, data=df, palette="Set2")
# C:\Users\bamoi\AppData\Local\Temp\ipykernel_21880\296896386.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="HTA", y=var, data=df, palette="Set2")
# C:\Users\bamoi\AppData\Local\Temp\ipykernel_21880\296896386.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="HTA", y=var, data=df, palette="Set2")
# C:\Users\bamoi\AppData\Local\Temp\ipykernel_21880\296896386.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="HTA", y=var, data=df, palette="Set2")
# C:\Users\bamoi\AppData\Local\Temp\ipykernel_21880\296896386.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="HTA", y=var, data=df, palette="Set2")
# C:\Users\bamoi\AppData\Local\Temp\ipykernel_21880\296896386.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="HTA", y=var, data=df, palette="Set2")
# C:\Users\bamoi\AppData\Local\Temp\ipykernel_21880\296896386.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="HTA", y=var, data=df, palette="Set2")

# %% [markdown]
# 📋 Variables catégorielles avec countplot

# %%
vars_cat = ["sexe_1H_2F", "ethnie_code", "statut_tabagique", "activite_moderate_10min"]

for var in vars_cat:
    plt.figure(figsize=(6, 4))
    sns.countplot(x=var, hue="HTA", data=df, palette="pastel")
    plt.title(f"Répartition de HTA selon {var}")
    plt.xlabel(var)
    plt.ylabel("Nombre de personnes")
    plt.legend(title="HTA")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Corrélations

# %% [markdown]
# 🔎 Sélection des colonnes numériques uniquement

# %%
df_numerique = df.select_dtypes(include=["float64", "int64", "bool"]).copy()

# %% [markdown]
# 🔗 Matrice de corrélation

# %%
correlation_matrix = df_numerique.corr()

# %% [markdown]
# 📌 Afficher la matrice triée par corrélation avec HTA

# %%
print("📈 Corrélations avec la variable HTA :")
print(correlation_matrix["HTA"].sort_values(ascending=False))
# Out:
# 📈 Corrélations avec la variable HTA :
# HTA                              1.000000
# age_annees                       0.626783
# tension_sys_moy_mmHg             0.607120
# tension_systolique_1_mmHg        0.600491
# tension_systolique_2_mmHg        0.596481
# tension_systolique_3_mmHg        0.590075
# tour_taille_cm                   0.452669
# tension_diastolique_1_mmHg       0.438397
# tension_dia_moy_mmHg             0.437814
# tension_diastolique_2_mmHg       0.421285
# tension_diastolique_3_mmHg       0.413622
# poids_kg                         0.408182
# imc                              0.367626
# taille_cm                        0.282941
# cholesterol_total_mgdl           0.135810
# statut_tabagique                 0.079984
# sodium_jour2_mg                  0.078189
# activite_vigoureuse_10min        0.052146
# ethnie_code                      0.048948
# sodium_jour1_mg                  0.048232
# activite_moderate_10min          0.035145
# SEQN                            -0.003587
# antecedent_familial_cardiaque   -0.005554
# sexe_1H_2F                      -0.008386
# frequence_cardiaque_1_bpm       -0.074229
# frequence_cardiaque_2_bpm       -0.102042
# frequence_cardiaque_3_bpm       -0.121372
# a_fume_100_cigarettes           -0.134158
# antecedent_cardiaque            -0.203968
# hta_diagnostiquee               -0.777769
# hta_traitement                        NaN
# Name: HTA, dtype: float64

# %% [markdown]
# 🔥 Heatmap de la matrice de corrélation

# %%
plt.figure(figsize=(14, 10))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm", square=True,
            cbar_kws={"shrink": .8}, linewidths=.5)
plt.title("🔗 Matrice de corrélation (Pearson)")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\bamoi\AppData\Local\Temp\ipykernel_21880\3769248514.py:5: UserWarning: Glyph 128279 (\N{LINK SYMBOL}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\bamoi\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128279 (\N{LINK SYMBOL}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# 💡 Option : heatmap centrée sur les variables les plus corrélées avec HTA

# %%
top_corr = correlation_matrix["HTA"].abs().sort_values(ascending=False)[1:11].index.tolist()

plt.figure(figsize=(10, 8))
sns.heatmap(df_numerique[top_corr + ["HTA"]].corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("🔍 Variables les plus corrélées avec HTA")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\bamoi\AppData\Local\Temp\ipykernel_21880\3703335599.py:6: UserWarning: Glyph 128269 (\N{LEFT-POINTING MAGNIFYING GLASS}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\bamoi\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128269 (\N{LEFT-POINTING MAGNIFYING GLASS}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # Comparaison selon HTA

# %% [markdown]
# 📊 Moyennes par groupe HTA (True / False)

# %%
print("📌 Moyennes par groupe HTA :")
moyennes_par_groupe = df.groupby("HTA")[[
    "age_annees", "imc", "tension_sys_moy_mmHg", "tension_dia_moy_mmHg",
    "cholesterol_total_mgdl", "poids_kg", "taille_cm", "sodium_jour1_mg"
]].mean().round(2)
print(moyennes_par_groupe)
# Out:
# 📌 Moyennes par groupe HTA :
#        age_annees    imc  tension_sys_moy_mmHg  tension_dia_moy_mmHg  \
# HTA
# False       24.06  24.66                111.15                 67.73
# True        59.75  31.46                135.94                 78.79
#
#        cholesterol_total_mgdl  poids_kg  taille_cm  sodium_jour1_mg
# HTA
# False                  173.55     57.05     152.37          3094.99
# True                   185.13     87.53     166.43          3287.59

# %% [markdown]
# 🔍 Écart-type par groupe HTA (utile pour comparaison)

# %%
print("\n📐 Écarts-types par groupe HTA :")
ecart_types = df.groupby("HTA")[[
    "age_annees", "imc", "tension_sys_moy_mmHg", "tension_dia_moy_mmHg",
    "cholesterol_total_mgdl", "poids_kg", "taille_cm", "sodium_jour1_mg"
]].std().round(2)
print(ecart_types)
# Out:
# 📐 Écarts-types par groupe HTA :
#        age_annees   imc  tension_sys_moy_mmHg  tension_dia_moy_mmHg  \
# HTA
# False       21.17  7.86                 11.93                  9.33
# True        15.19  7.77                 20.50                 13.20
#
#        cholesterol_total_mgdl  poids_kg  taille_cm  sodium_jour1_mg
# HTA
# False                   38.54     32.49      24.95          1830.46
# True                    42.66     24.17      10.25          1754.55

# %% [markdown]
# 📈 Visualisation : comparaison par barplots

# %%
moyennes_par_groupe.T.plot.bar(figsize=(10, 6))
plt.title("Comparaison des moyennes selon HTA")
plt.ylabel("Valeurs moyennes")
plt.xlabel("Variables")
plt.xticks(rotation=45)
plt.legend(title="HTA")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Nouvelles variables

# %% [markdown]
# 🧓 Création de tranches d’âge

# %%
df["groupe_age"] = pd.cut(df["age_annees"],
                          bins=[0, 18, 30, 45, 60, 80, 120],
                          labels=["<18", "18–30", "30–45", "45–60", "60–80", "80+"])

# %% [markdown]
# 🧂 Moyenne sodium jour 1 + jour 2

# %%
df["sodium_moyen_mg"] = df[["sodium_jour1_mg", "sodium_jour2_mg"]].mean(axis=1)

# %% [markdown]
# ❤️ Fréquence cardiaque moyenne (si données disponibles)

# %%
if "frequence_cardiaque_1_bpm" in df.columns:
    df["frequence_cardiaque_moy_bpm"] = df[[
        "frequence_cardiaque_1_bpm",
        "frequence_cardiaque_2_bpm",
        "frequence_cardiaque_3_bpm"
    ]].mean(axis=1)

# %% [markdown]
# 🔴 Création d’un indicateur "HTA isolée systolique"

# %%
df["hta_isolee_systolique"] = (
    (df["tension_sys_moy_mmHg"] >= 140) & (df["tension_dia_moy_mmHg"] < 90)
)

# %% [markdown]
# 💾 Sauvegarder le nouveau dataset avec les variables créées

# %%
df.to_csv("hta_nhanes_enrichi.csv", index=False)
print("✅ Nouvelles variables ajoutées et fichier sauvegardé sous : hta_nhanes_enrichi.csv")
# Out:
# ✅ Nouvelles variables ajoutées et fichier sauvegardé sous : hta_nhanes_enrichi.csv

# %% [markdown]
# # Analyses et interprétations finales

# %% [markdown]
# Charger le dataset enrichi

# %%
df = pd.read_csv("hta_nhanes_enrichi.csv")

# %% [markdown]
# 📌 1. Répartition HTA selon les tranches d’âge

# %%
hta_age = pd.crosstab(df["groupe_age"], df["HTA"], normalize="index") * 100
hta_age.plot(kind="bar", stacked=True, figsize=(8, 5), colormap="coolwarm")
plt.title("📊 Pourcentage de personnes hypertendues par tranche d’âge")
plt.ylabel("% de personnes")
plt.xlabel("Tranche d’âge")
plt.legend(["Non HTA", "HTA"], title="HTA")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\bamoi\AppData\Local\Temp\ipykernel_21880\3985954627.py:7: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\bamoi\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# 📌 2. Répartition HTA selon le sexe

# %%
hta_sexe = pd.crosstab(df["sexe_1H_2F"], df["HTA"], normalize="index") * 100
hta_sexe.index = ["Homme", "Femme"]
hta_sexe.plot(kind="bar", stacked=True, figsize=(6, 4), colormap="viridis")
plt.title("📊 Hypertension par sexe")
plt.ylabel("%")
plt.xlabel("Sexe")
plt.legend(["Non HTA", "HTA"], title="HTA")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\bamoi\AppData\Local\Temp\ipykernel_21880\1860881577.py:8: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) Arial.
#   plt.tight_layout()
# C:\Users\bamoi\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) Arial.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# 📌 3. Variable importante : IMC selon HTA

# %%
sns.boxplot(x="HTA", y="imc", data=df, palette="Set2")
plt.title("Distribution de l'IMC selon la présence d'HTA")
plt.xlabel("HTA")
plt.ylabel("Indice de Masse Corporelle (IMC)")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\bamoi\AppData\Local\Temp\ipykernel_21880\2727003988.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="HTA", y="imc", data=df, palette="Set2")

# %% [markdown]
# 📌 4. Conclusion : résumé des tendances principales

# %%
print("📌 Interprétations principales :")
print("- L’hypertension augmente fortement avec l’âge, surtout après 45 ans.")
print("- Les hommes sont légèrement plus touchés que les femmes.")
print("- Les personnes hypertendues ont en moyenne un IMC plus élevé.")
print("- Une tension systolique élevée seule (HTA isolée) est fréquente chez les personnes âgées.")
# Out:
# 📌 Interprétations principales :
# - L’hypertension augmente fortement avec l’âge, surtout après 45 ans.
# - Les hommes sont légèrement plus touchés que les femmes.
# - Les personnes hypertendues ont en moyenne un IMC plus élevé.
# - Une tension systolique élevée seule (HTA isolée) est fréquente chez les personnes âgées.
